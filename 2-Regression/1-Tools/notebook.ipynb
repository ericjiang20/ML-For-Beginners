# %% [markdown]
# # Welcome to your notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets , linear_model, model_selection

# #load the data diabetes dataset 
# x, y = datasets.load_diabetes(return_X_y=True)

# %%
from sklearn import linear_model, model_selection
reg = linear_model.LinearRegression()
reg.fit([[0,0],[1,1],[2,2]],[0,1,2])
# Out:
# LinearRegression()

# %%
array=([0.5,0.5])

# %%
import matplotlib.pyplot as plt 
import numpy as np

from sklearn import datasets, linear_model, model_selection 
from sklearn.metrics import mean_squared_error, r2_score

# %%
#load the diabetes dataset 
X, y = datasets.load_diabetes(return_X_y=True)

#use only one feature
X = X[:, np.newaxis, 2]

# %%
#split the data into training/testing sets
X_train, X_test = X[:-20], X[-20:]
y_train, y_test = y[:-20], y[-20:]

# %%
regr = linear_model.LinearRegression()

#traing the model using the training sets
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Make predictions using the testing set
y_pred = regr.predict(X_test)

# %%
#The coefficients 
print("Coefficeints: \n", regr.coef_)
# Out:
# Coefficeints:
#  [938.23786125]

# %%
#The mean squared erro 
print("Mean squred error: %.2f" % mean_squared_error(y_test, y_pred))
# Out:
# Mean squred error: 2548.07

# %%
#the coefficient of determination: 1 is the perfect prediction
print("Coefficeint of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficeint of determination: 0.47

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)

# %%
plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %%
plt.show()
